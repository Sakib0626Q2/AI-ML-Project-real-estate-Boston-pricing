# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from pandas.plotting import scatter_matrix
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import sklearn.metrics as metrics
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from joblib import dump, load

# %%
# from google.colab import files
# files.upload()

# %%
housing = pd.read_csv("./HousingBoston.csv")
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       505 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  505.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284535
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.703310
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
housing['CHAS'].value_counts()
# Out:
# CHAS
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
housing['CRIM'].value_counts()
# Out:
# CRIM
# 0.01501     2
# 14.33370    2
# 0.03466     1
# 0.05083     1
# 0.03738     1
#            ..
# 1.27346     1
# 1.42502     1
# 1.34284     1
# 1.22358     1
# 0.13914     1
# Name: count, Length: 504, dtype: int64

# %%
housing.hist(bins=50, figsize = (20, 15))
# Out:
# array([[<Axes: title={'center': 'CRIM'}>, <Axes: title={'center': 'ZN'}>,
#         <Axes: title={'center': 'INDUS'}>,
#         <Axes: title={'center': 'CHAS'}>],
#        [<Axes: title={'center': 'NOX'}>, <Axes: title={'center': 'RM'}>,
#         <Axes: title={'center': 'AGE'}>, <Axes: title={'center': 'DIS'}>],
#        [<Axes: title={'center': 'RAD'}>, <Axes: title={'center': 'TAX'}>,
#         <Axes: title={'center': 'PTRATIO'}>,
#         <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'LSTAT'}>,
#         <Axes: title={'center': 'MEDV'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## Train-Test Splitting

# %%
# for learning purpose

def split_train_test(data, test_ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    print(shuffled)
    test_set_size = int(len(data)* test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
# train_set, test_set = split_train_test(housing, 0.2)

# %%
# print(f"Rows in train set: {len(train_set)} \nRows in test set: {len(test_set)}")

# %%
train_set, test_set = train_test_split(housing, test_size = 0.2, random_state = 42)
print(f"Rows in train set: {len(train_set)} \nRows in test set: {len(test_set)}")
# Out:
# Rows in train set: 404
# Rows in test set: 102

# %%
split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2, random_state = 42)
for train_index, test_index in split.split(housing, housing['CHAS']):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    376
# 1     28
# Name: count, dtype: int64

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    95
# 1     7
# Name: count, dtype: int64

# %%
376/28
# Out:
# 13.428571428571429

# %%
95/7
# Out:
# 13.571428571428571

# %%
housing = strat_train_set.copy()

# %% [markdown]
# ## Looking for Correlations

# %%
corr_matrix = housing.corr()
corr_matrix['MEDV'].sort_values(ascending = 0)
# Out:
# MEDV       1.000000
# RM         0.680176
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
corr_matrix['MEDV']
# Out:
# CRIM      -0.393715
# ZN         0.339741
# INDUS     -0.473516
# CHAS       0.205066
# NOX       -0.422873
# RM         0.680176
# AGE       -0.364596
# DIS        0.240451
# RAD       -0.374693
# TAX       -0.456657
# PTRATIO   -0.493534
# B          0.361761
# LSTAT     -0.740494
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %%
attributes = ["MEDV", "RM", "ZN", "LSTAT"]
scatter_matrix(housing[attributes], figsize = (12, 8))
# Out:
# array([[<Axes: xlabel='MEDV', ylabel='MEDV'>,
#         <Axes: xlabel='RM', ylabel='MEDV'>,
#         <Axes: xlabel='ZN', ylabel='MEDV'>,
#         <Axes: xlabel='LSTAT', ylabel='MEDV'>],
#        [<Axes: xlabel='MEDV', ylabel='RM'>,
#         <Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='ZN', ylabel='RM'>,
#         <Axes: xlabel='LSTAT', ylabel='RM'>],
#        [<Axes: xlabel='MEDV', ylabel='ZN'>,
#         <Axes: xlabel='RM', ylabel='ZN'>,
#         <Axes: xlabel='ZN', ylabel='ZN'>,
#         <Axes: xlabel='LSTAT', ylabel='ZN'>],
#        [<Axes: xlabel='MEDV', ylabel='LSTAT'>,
#         <Axes: xlabel='RM', ylabel='LSTAT'>,
#         <Axes: xlabel='ZN', ylabel='LSTAT'>,
#         <Axes: xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing.plot(kind = "scatter", x = "RM", y = "MEDV", alpha = 0.4)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %% [markdown]
# ### Attribute Combinations

# %%
housing["TAXRM"] = housing['TAX']/housing['RM']
housing["TAXRM"]
# Out:
# 254     51.571709
# 348     42.200452
# 476    102.714374
# 321     45.012547
# 326     45.468948
#           ...
# 155     65.507152
# 423    109.126659
# 98      35.294118
# 455    102.068966
# 216     46.875000
# Name: TAXRM, Length: 404, dtype: float64

# %%
housing.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
#
#      PTRATIO       B  LSTAT  MEDV       TAXRM
# 254     16.4  392.89   6.57  21.9   51.571709
# 348     17.0  390.94   5.99  24.5   42.200452
# 476     20.2  396.21  18.68  16.7  102.714374
# 321     19.6  396.90   6.87  23.1   45.012547
# 326     19.6  396.90   6.15  23.0   45.468948

# %%
corr_matrix = housing.corr()
corr_matrix['MEDV'].sort_values(ascending = 0)
# Out:
# MEDV       1.000000
# RM         0.680176
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# TAXRM     -0.525250
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
housing.plot(kind = "scatter", x = "TAXRM", y = "MEDV", alpha = 0.4)
# Out:
# <Axes: xlabel='TAXRM', ylabel='MEDV'>

# %%
housing = strat_train_set.drop("MEDV", axis=1)
housing_labels = strat_train_set["MEDV"].copy()

# %%
a = housing.dropna(subset = ["RM"])
a.shape
# Out:
# (403, 13)

# %%
median = housing["RM"].median()
median
# Out:
# 6.209

# %%
housing["RM"]
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
housing["RM"].fillna(median)
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
housing.shape
# Out:
# (404, 13)

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  403.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.279772
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.713864
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878500
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630500
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
imputer = SimpleImputer(strategy="median")
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.20900e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
imputer.statistics_.shape
# Out:
# (13,)

# %%
X = imputer.transform(housing)

# %%
housing_tr = pd.DataFrame(X, columns = housing.columns)

# %%
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.279597
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.712987
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %% [markdown]
# ## Scikit-learn Design

# %% [markdown]
# ### Creating a Pipeline

# %%
my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler', StandardScaler())
])

# %%
housing_num_tr = my_pipeline.fit_transform(housing_tr)

# %%
housing_num_tr
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %% [markdown]
# ### Selecting a desired model

# %%
# model = LinearRegression()
# model = DecisionTreeRegressor()
model = RandomForestRegressor()
model.fit(housing_num_tr, housing_labels)
# Out:
# RandomForestRegressor()

# %%
some_data = housing.iloc[:5]

# %%
some_labels = housing_labels.iloc[:5]

# %%
prepared_data = my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([22.478, 25.265, 16.331, 23.355, 23.541])

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %%
housing_predictions = model.predict(housing_num_tr)
mse = metrics.mean_squared_error(housing_labels, housing_predictions)
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(1.2387627630697962)

# %% [markdown]
# ## Using better evalution technique - Cross Validation

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, housing_num_tr, housing_labels,
                         scoring="neg_mean_squared_error", cv=10)
rmse_scores = np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([2.97964578, 2.79152046, 4.33150318, 2.65897634, 3.39576917,
#        2.6167281 , 4.64340705, 3.36688937, 3.4643939 , 3.22965951])

# %%
def print_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

# %%
print_scores(rmse_scores)
# Out:
# Scores: [2.97964578 2.79152046 4.33150318 2.65897634 3.39576917 2.6167281
#  4.64340705 3.36688937 3.4643939  3.22965951]
# Mean: 3.347849286730649
# Standard deviation: 0.6426830417698476

# %% [markdown]
# ## Saving The Model

# %%
dump(model, 'realestate_model.joblib')
# Out:
# ['realestate_model.joblib']

# %% [markdown]
# ## Testing the Model on test data

# %%
X_test = strat_test_set.drop("MEDV", axis=1)
Y_test = strat_test_set["MEDV"].copy()
X_test_prepared = my_pipeline.transform(X_test)
final_predictions = model.predict(X_test_prepared)
final_mse = metrics.mean_squared_error(Y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
print(final_predictions, list(Y_test))
# Out:
# [24.859 11.506 25.573 21.827 18.507 15.149 20.065 14.567 32.059 40.856
#  19.634 11.944 24.575 27.041 19.588 11.117 31.626 14.246 23.636 18.929
#  19.801 17.813 17.776 22.15  18.818 32.533 16.532 33.94   8.88  33.67
#  24.466 21.351 22.934 11.252 20.663 11.146 42.342 24.6   23.68  42.101
#  24.02  29.631 20.132 21.021 18.515 33.186 44.249 20.142 20.509 22.003
#  21.091 14.581 21.123 15.116 25.18  33.528 42.693 29.2   19.208 20.779
#  47.073  9.979 19.33  24.454 15.077 32.935 19.463 17.932 19.047 35.015
#  25.67  22.784 21.069 22.472 34.492 13.086 16.017 19.424 20.864 21.507
#  22.583 21.293 14.224 22.986 20.657 21.189 14.08  21.534 21.888 23.147
#  18.839 27.053  7.421 26.924 18.514 29.217 19.837 31.216 14.277 27.277
# ...

# %%
final_rmse
# Out:
# np.float64(2.9915071370431967)

# %%
prepared_data[0]
# Out:
# array([-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
#        -0.24097129, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
#        -0.97491834,  0.41164221, -0.86091034])

# %% [markdown]
# # Task
# Load the saved model "realestate_model.joblib" and create an interactive GUI using `ipywidgets` for real estate price prediction. The GUI should allow users to input values for 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', and 'LSTAT', and then display the predicted housing price.

# %% [markdown]
# ## Load Model and Pipeline
#
# ### Subtask:
# Load the saved 'realestate_model.joblib' and re-create the `my_pipeline` used for preprocessing, ensuring the model can be used for new predictions.

# %% [markdown]
# **Reasoning**:
# The subtask requires loading a saved model and recreating the preprocessing pipeline. The first step is to load the saved model from 'realestate_model.joblib' and then instantiate the `my_pipeline` object. Then, I need to create `housing_features` from `strat_train_set` and fit the `my_pipeline` on `housing_features`.

# %%
model = load('realestate_model.joblib')

my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler', StandardScaler())
])

housing_features = strat_train_set.drop("MEDV", axis=1)
my_pipeline.fit(housing_features)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('std_scaler', StandardScaler())])

# %% [markdown]
# ## Define Prediction Function
#
# ### Subtask:
# Create a Python function that takes the raw input features, applies the loaded preprocessing pipeline, and then uses the loaded model to make a housing price prediction.

# %% [markdown]
# **Reasoning**:
# To define the prediction function, I need to create a Python function that takes the raw input features, converts them into a DataFrame, applies the `my_pipeline` for preprocessing, and then uses the `model` to make a prediction, finally returning the predicted value.

# %%
def predict_price(CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT):
    input_data = pd.DataFrame([[CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT]],
                               columns=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'])

    # Apply the preprocessing pipeline
    prepared_input = my_pipeline.transform(input_data)

    # Make prediction using the loaded model
    prediction = model.predict(prepared_input)

    return prediction[0]

print("Prediction function 'predict_price' defined.")
# Out:
# Prediction function 'predict_price' defined.

# %% [markdown]
# ## Create Input Widgets
#
# ### Subtask:
# Generate interactive `ipywidgets` (e.g., FloatText, Dropdown) for each feature required by the model (CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT). This will allow users to input values for prediction.

# %% [markdown]
# **Reasoning**:
# First, import the necessary libraries `ipywidgets` and `IPython.display` to create and display the interactive widgets.

# %%
import ipywidgets as widgets
from IPython.display import display

print("ipywidgets and IPython.display imported.")
# Out:
# ipywidgets and IPython.display imported.

# %% [markdown]
# **Reasoning**:
# Now I will create interactive widgets for each input feature, using appropriate widget types and default values based on the training data statistics to provide sensible starting points for the user.

# %%
description = housing_features.describe()

crim_widget = widgets.FloatText(
    description='CRIM (per capita crime rate):',
    value=description.loc['mean', 'CRIM'],
    step=0.1,
    min=0,
    continuous_update=False
)
zn_widget = widgets.FloatText(
    description='ZN (proportion of residential land zoned for lots over 25,000 sq.ft.):',
    value=description.loc['mean', 'ZN'],
    step=1.0,
    min=0,
    continuous_update=False
)
indus_widget = widgets.FloatText(
    description='INDUS (proportion of non-retail business acres per town):',
    value=description.loc['mean', 'INDUS'],
    step=0.1,
    min=0,
    continuous_update=False
)
chas_widget = widgets.Dropdown(
    options=[0, 1],
    value=0,
    description='CHAS (Charles River dummy variable, 1 if tract bounds river; 0 otherwise):',
    continuous_update=False
)
nox_widget = widgets.FloatText(
    description='NOX (nitric oxides concentration (parts per 10 million)):',
    value=description.loc['mean', 'NOX'],
    step=0.01,
    min=0,
    continuous_update=False
)
rm_widget = widgets.FloatText(
    description='RM (average number of rooms per dwelling):',
    value=description.loc['mean', 'RM'],
    step=0.01,
    min=0,
    continuous_update=False
)
age_widget = widgets.FloatText(
    description='AGE (proportion of owner-occupied units built prior to 1940):',
    value=description.loc['mean', 'AGE'],
    step=1.0,
    min=0,
    continuous_update=False
)
dis_widget = widgets.FloatText(
    description='DIS (weighted distances to five Boston employment centres):',
    value=description.loc['mean', 'DIS'],
    step=0.1,
    min=0,
    continuous_update=False
)
rad_widget = widgets.IntText(
    description='RAD (index of accessibility to radial highways):',
    value=int(description.loc['mean', 'RAD']),
    step=1,
    min=0,
    continuous_update=False
)
tax_widget = widgets.IntText(
    description='TAX (full-value property tax rate per $10,000):',
    value=int(description.loc['mean', 'TAX']),
    step=1,
    min=0,
    continuous_update=False
)
ptratio_widget = widgets.FloatText(
    description='PTRATIO (pupil-teacher ratio by town):',
    value=description.loc['mean', 'PTRATIO'],
    step=0.1,
    min=0,
    continuous_update=False
)
b_widget = widgets.FloatText(
    description='B (1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town):',
    value=description.loc['mean', 'B'],
    step=1.0,
    min=0,
    continuous_update=False
)
lstat_widget = widgets.FloatText(
    description='LSTAT (% lower status of the population):',
    value=description.loc['mean', 'LSTAT'],
    step=0.1,
    min=0,
    continuous_update=False
)

print("Widgets for all input features created.")
# Out:
# Widgets for all input features created.

# %% [markdown]
# **Reasoning**:
# Now that the individual input widgets are created, I need to create an output widget to display the prediction and then arrange all input widgets and the output widget into an interactive interface.

# %%
output = widgets.Output()

# Create an interactive display for the widgets and the prediction function
interactive_output = widgets.interactive_output(predict_price, {
    'CRIM': crim_widget,
    'ZN': zn_widget,
    'INDUS': indus_widget,
    'CHAS': chas_widget,
    'NOX': nox_widget,
    'RM': rm_widget,
    'AGE': age_widget,
    'DIS': dis_widget,
    'RAD': rad_widget,
    'TAX': tax_widget,
    'PTRATIO': ptratio_widget,
    'B': b_widget,
    'LSTAT': lstat_widget
})

# Display the widgets and the output
display(
    widgets.VBox([
        widgets.HBox([crim_widget, zn_widget]),
        widgets.HBox([indus_widget, chas_widget]),
        widgets.HBox([nox_widget, rm_widget]),
        widgets.HBox([age_widget, dis_widget]),
        widgets.HBox([rad_widget, tax_widget]),
        widgets.HBox([ptratio_widget, b_widget]),
        widgets.HBox([lstat_widget]),
        widgets.HBox([widgets.Label("Predicted Housing Price:"), interactive_output])
    ])
)

print("Interactive GUI for housing price prediction created.")
# Out:
# ...
# Interactive GUI for housing price prediction created.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The pre-trained real estate prediction model, `realestate_model.joblib`, was successfully loaded.
# *   A preprocessing pipeline, `my_pipeline`, comprising a median `SimpleImputer` and `StandardScaler`, was accurately recreated and fitted using the training data's features.
# *   A Python function, `predict_price`, was developed to accept 13 distinct input features, apply the defined `my_pipeline` for preprocessing, and then generate a housing price prediction using the loaded model.
# *   An interactive GUI was successfully constructed using `ipywidgets`. This GUI includes `FloatText` widgets for continuous numerical features, `IntText` for integer-based features like 'RAD' and 'TAX', and a `Dropdown` for the binary 'CHAS' feature.
# *   Default values for the input widgets were pre-populated using the mean of each corresponding feature from the original `housing_features` dataset, providing a sensible starting point for user interaction.
# *   The GUI effectively integrates the input widgets with the `predict_price` function, allowing for real-time housing price predictions based on user-adjusted inputs.
#
# ### Insights or Next Steps
#
# *   The interactive GUI provides an immediate and intuitive way for stakeholders to test the model and understand the impact of various input features on housing price predictions, fostering transparency and trust in the model.
# *   Future enhancements could include implementing input validation directly within the widgets (e.g., setting `max` values, more granular `step` sizes, or custom validators) to guide users and prevent unrealistic inputs, ensuring more robust interactions with the prediction model.
